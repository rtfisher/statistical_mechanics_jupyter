# %%
# plot P vs (V,T) surface
import numpy as np                  # get numpy functions
import matplotlib.pyplot as plt     # get matplotlib plot functions
from mpl_toolkits.mplot3d import Axes3D     # for surface plots
# %matplotlib notebook

# %%
T = np.linspace(1., 10, 20)
V = np.linspace(1., 10, 20)
V, T = np.meshgrid(V, T)
nR = 1.0
P = nR*T/V

# %%
fig = plt.figure()   # add surface plot with strides and color map 
axis=fig.add_subplot(111, projection='3d')  # add subplot
axis.plot_surface(V, T, P, rstride=1, cstride=1)
#linewidth=0, cmap=plt.cm.spectral)
axis.set_xlabel('V'), axis.set_ylabel('T'), axis.set_zlabel('P')
# Out:
# <img src="data:image/png;base64,..." width="640">
# (Text(0.5, 0, 'V'), Text(0.5, 0, 'T'), Text(0.5, 0, 'P'))
